# %% [markdown]
# <a href="https://colab.research.google.com/github/cordeiroiago/cordeiroiago/blob/main/jogodaforca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def jogar():
    palavras = ["guilherme", "indio", "pardo", "perdo", "iago", "rian", "virto"]
    palavra_secreta = random.choice(palavras).upper()
    letras_acertadas = ["_" for letra in palavra_secreta]

    enforcou = False
    acertou = False
    erros = 0
    tentativas = 6 # Número de vidas

    print("Bem vindo ao jogo da Forca!")
    print(" ".join(letras_acertadas))

    while(not enforcou and not acertou):
        chute = input("Qual letra?  ").strip().upper()

        if(chute in palavra_secreta):
            index = 0
            for letra in palavra_secreta:
                if(chute == letra):
                    letras_acertadas[index] = letra
                index += 1
        else:
            erros += 1
            print(f"Você errou!restam {tentativas - erros} tentativas.")

        enforcou = erros == tentativas
        acertou = "_" not in letras_acertadas

        print(" ".join(letras_acertadas))

    if(acertou):
        print("Boa!! você ganhou!")
    else:
        print(f"Você perdeu! A palavra era {palavra_secreta}")
    print("Fim do jogo")

# Executa o jogo
jogar()
# Out:
# Bem vindo ao jogo da Forca!
# _ _ _ _ _ _
# Qual letra?  p
# P _ _ _ _ _
# Qual letra?  y
# P Y _ _ _ _
# Qual letra?  t
# P Y T _ _ _
# Qual letra?  h
# P Y T H _ _
# Qual letra?  o
# P Y T H O _
# Qual letra?  n
# P Y T H O N
# Boa!! você ganhou!
# Fim do jogo
